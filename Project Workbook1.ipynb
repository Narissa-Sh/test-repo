# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Narissa-Sh/test-repo/master/bitcoin.csv'
data = pd.read_csv(url, na_filter=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
plt.rcParams['figure.figsize'] = (17, 6)
plt.rcParams['font.size'] = 14

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data['Year'] = data.index.year
data['Month'] = data.index.month
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-682ba06be1e0> in <module>()
# ----> 1 data['Date'] = pd.to_datetime(data['Date'])
#       2 data.set_index('Date', inplace=True)
#       3
#       4 data['Year'] = data.index.year
#       5 data['Month'] = data.index.month
#
# C:\Users\U0123724\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\U0123724\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\U0123724\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\U0123724\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\U0123724\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Date'

# %%
data.head()
# Out:
#             Open  High   Low  Last          Vol     Diff       Hash  LS  \
# Date
# 2012-04-19  5.17  5.18  5.06  5.13  288111.6243  1577913  12.236407  S0
# 2012-04-20  5.15  5.38  5.09  5.38  288111.6243  1577913  12.236407  S0
# 2012-04-21  5.40  5.43  5.19  5.24  336827.7813  1577913  11.530460  S0
# 2012-04-22  5.24  5.25  5.17  5.17  336827.7813  1577913  11.530460  S0
# 2012-04-23  5.20  5.25  5.00  5.00  279236.4544  1577913  11.608899  S0
#
#             LS_TH_S   LS_P  ...     HS HS_TH_S    HS_P  HS_MWh_TH      UK_EP  \
# Date                        ...
# 2012-04-19     0.09  149.5  ...    S0+     0.5  1129.5       7.56  73.481478
# 2012-04-20     0.09  149.5  ...    S0+     0.5  1129.5       7.56  73.041720
# 2012-04-21     0.09  149.5  ...    S0+     0.5  1129.5       7.56  73.041720
# 2012-04-22     0.09  149.5  ...    S0+     0.5  1129.5       7.56  73.041720
# 2012-04-23     0.09  149.5  ...    S0+     0.5  1129.5       7.56  74.744010
#
#             US_EP      AUS_EP    RU_EP  Year  Month
# Date
# 2012-04-19  28.19  39.0783727  30.0426  2012      4
# 2012-04-20  28.45  45.4834287  29.5864  2012      4
# 2012-04-21  26.10  36.9784395  30.5039  2012      4
# 2012-04-22  27.02  30.5841321  25.7296  2012      4
# 2012-04-23  32.00   38.192742  30.6223  2012      4
#
# [5 rows x 21 columns]

# %%
data.Last.plot()

# %%
data.Hash.plot()

# %%
data.Diff.plot()
